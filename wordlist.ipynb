# %%
#手機
from itertools import product
import time
f = open (r'C:/Users/tomto/abcd.txt','w')


list=product('0123456789', repeat=6)
tt = time.time()
for i in list:
    print('0988',*i,sep = "",file=f)  
    print('0984',*i,sep = "",file=f)  
    print('0978',*i,sep = "",file=f)  
    print('0975',*i,sep = "",file=f)  
    print('0974',*i,sep = "",file=f)  
    print('0972',*i,sep = "",file=f)  
    print('0966',*i,sep = "",file=f)  
    print('0965',*i,sep = "",file=f)  
    print('0963',*i,sep = "",file=f)  
    print('0937',*i,sep = "",file=f)  
    print('0934',*i,sep = "",file=f)  
    print('0933',*i,sep = "",file=f)  
    print('0932',*i,sep = "",file=f)  
    print('0928',*i,sep = "",file=f)  
    print('0921',*i,sep = "",file=f)  
    print('0919',*i,sep = "",file=f)  
    print('0912',*i,sep = "",file=f)  
    print('0911',*i,sep = "",file=f)  
    print('0910',*i,sep = "",file=f)  
    print('0905',*i,sep = "",file=f) 
    print('0906',*i,sep = "",file=f)  
    print('0907',*i,sep = "",file=f)  
    print('0977',*i,sep = "",file=f)  
    print('0980',*i,sep = "",file=f)  
    print('0982',*i,sep = "",file=f)  
    print('0985',*i,sep = "",file=f)  
    print('0908',*i,sep = "",file=f)  
    print('0971',*i,sep = "",file=f)  
    print('0973',*i,sep = "",file=f)  
    print('0986',*i,sep = "",file=f)  
    print('0909',*i,sep = "",file=f)  
    print('0914',*i,sep = "",file=f)  
    print('0918',*i,sep = "",file=f)  
    print('0920',*i,sep = "",file=f)  
    print('0922',*i,sep = "",file=f)  
    print('0923',*i,sep = "",file=f)  
    print('0924',*i,sep = "",file=f)  
    print('0929',*i,sep = "",file=f)  
    print('0931',*i,sep = "",file=f)  
    print('0935',*i,sep = "",file=f)  
    print('0939',*i,sep = "",file=f)  
    print('0952',*i,sep = "",file=f)  
    print('0953',*i,sep = "",file=f)  
    print('0956',*i,sep = "",file=f)  
    print('0958',*i,sep = "",file=f)  
    print('0960',*i,sep = "",file=f)  
    print('0961',*i,sep = "",file=f)  
    print('0966',*i,sep = "",file=f)  
    print('0970',*i,sep = "",file=f)  
    print('0971',*i,sep = "",file=f)  
    print('0979',*i,sep = "",file=f)  
    print('0983',*i,sep = "",file=f)  
    print('0987',*i,sep = "",file=f)  
    print('0900',*i,sep = "",file=f)  
    print('0903',*i,sep = "",file=f)  
    print('0913',*i,sep = "",file=f)  
    print('0915',*i,sep = "",file=f)  
    print('0916',*i,sep = "",file=f)  
    print('0917',*i,sep = "",file=f)  
    print('0925',*i,sep = "",file=f)  
    print('0926',*i,sep = "",file=f)  
    print('0927',*i,sep = "",file=f)  
    print('0930',*i,sep = "",file=f)  
    print('0931',*i,sep = "",file=f)  
    print('0936',*i,sep = "",file=f)  
    print('0938',*i,sep = "",file=f)  
    print('0954',*i,sep = "",file=f)  
    print('0955',*i,sep = "",file=f)  
    print('0960',*i,sep = "",file=f)  
    print('0962',*i,sep = "",file=f)  
    print('0966',*i,sep = "",file=f)  
    print('0967',*i,sep = "",file=f)  
    print('0968',*i,sep = "",file=f)  
    print('0976',*i,sep = "",file=f)
    print('0981',*i,sep = "",file=f)  
    print('0989',*i,sep = "",file=f)
print('Time used: {} sec'.format(time.time()-tt),file=f)
f.close()

# %%
#數字8碼
from itertools import product
import time
f = open (r'C:/Users/tomto/abcd.txt','w')


list=product('0123456789', repeat=8)
tt = time.time()
for i in list:
    print(*i,sep = "",file=f)  

print('Time used: {} sec'.format(time.time()-tt),file=f)
f.close()
